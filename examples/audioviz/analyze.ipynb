# %% [markdown]
# # Setup
#
# This code is most likely to work on `green.uvt.nl` or `blue.uvt.nl`.
#
# I work with the following environment:
#
# ```
# export OMP_NUM_THREADS=2
# export THEANO_FLAGS=floatX=float32,device=gpu0,force_device=True,nvcc.fastmath=True,nvcc.flags=-arch=sm_30,cuda.root=/home/gchrupala/cuda-7.5
# export LD_LIBRARY_PATH=/home/gchrupala/cuda-7.5/lib64:$LD_LIBRARY_PATH
# export CPATH=/home/gchrupala/cuda-7.5/include:$CPATH
# export LIBRARY_PATH=/home/gchrupala/cuda-7.5/lib64:$LD_LIBRARY_PATH
# ```

# %%
import numpy
import imaginet.task as task
# Out:
# Using gpu device 1: GeForce GTX 980 Ti (CNMeM is disabled, cuDNN 5005)

# %% [markdown]
# # Loading models
#
# Load models trained on flickr8k captions (clean and noisy). We'll use the small flickr8k models as an example.

# %%
model_clean = task.load("/home/gchrupala/reimaginet/examples/audioviz/mfcc-flickr8k.zip")
model_noisy = task.load("/home/gchrupala/reimaginet/examples/audioviz/noisy-mfcc-flickr8k.zip")

# %% [markdown]
# # Loading data
#
# Load flickr8k data. This relies on the following files in the reimaginet directory:
# ```
# data/flickr8k/dataset.json
# data/flickr8k/vgg_feats.mat
# data/flickr8k/dataset.mfcc.npy
# data/flickr8k/dataset.noisy.mfcc.npy
# ```

# %%
import imaginet.data_provider as dp

# clean speech
prov_clean = dp.getDataProvider('flickr8k', root='/home/gchrupala/reimaginet', audio_kind='mfcc')
# noisy speech
prov_noisy = dp.getDataProvider('flickr8k', root='/home/gchrupala/reimaginet', audio_kind='noisy.mfcc')
# Out:
# Could not read file /home/gchrupala/reimaginet/data/flickr8k/dataset.ipa.jsonl.gz: IPA transcription not available
# Could not read file /home/gchrupala/reimaginet/data/flickr8k/dataset.ipa.jsonl.gz: IPA transcription not available

# %% [markdown]
# Grab all the validation sentences

# %%
sent_val_clean = list(prov_clean.iterSentences(split='val'))
print sent_val_clean[0]['raw']
print sent_val_clean[0]['audio'].shape
# Out:
# the boy laying face down on a skateboard is being pushed along the ground by another boy .
# (587, 13)

# %% [markdown]
# # Running the model

# %% [markdown]
# Run some sentences through the model and get the sentence embeddings. The function `a4.encode_sentences` is pretty fast as runs audios through the model in batches (to do so it will pad sentences in a batch to the same number of timesteps).

# %%
import imaginet.defn.audiovis4 as a4

data = [ numpy.asarray(sent['audio'], dtype='float32') for sent in sent_val_clean ]
embeddings = a4.encode_sentences(model_clean, data)

# %%
embeddings.shape
# Out:
# (5000, 1024)

# %% [markdown]
# You can also get the intermediate representations (states of hidden layers). Note that for this particular model the states of the top hidden layer at the last timestep are **NOT** equal to the sentence embeddings, as there is an additional attention-like lookback operation to get the final embeddings.

# %%
a4 = reload(a4)
states = a4.layer_states(model_clean, data)

# %%
states[4000].shape
# Out:
# (352, 3, 1024)

# %% [markdown]
# The three axes are: (timestep, layer, unit)

# %% [markdown]
# **Caveat**: the functions `a4.encode_sentences` and `a4.layer_states` work with batches of inputs, and they will internally pad these inputs such that each item in a batch is the same length. This means that the same sentences may have slightly different state activations, depending on what other items are in the batch.
# To circumvent it, you can run inputs through these functions one-by-one, at the cost of slowness.

# %%
# Get the states for a single input
a4.layer_states(model_clean, [data[0]])
# Out:
# [array([[[ 0.4754402 ,  0.22252056,  0.2905919 , ...,  0.00344204,
#            0.0021482 , -0.23447657],
#          [ 0.13785779,  0.09046656, -0.33705404, ..., -0.12322853,
#           -0.10360455, -0.02720204],
#          [ 0.33362374,  0.28243464,  0.16381931, ...,  0.2339962 ,
#           -0.1588849 , -0.38799778]],
#
#         [[ 0.89972067,  0.26148528,  0.92190057, ...,  0.07342996,
#            0.08655055, -0.65269101],
#          [ 0.01655018, -0.12976605, -0.32565439, ..., -0.18030542,
#           -0.32976285, -0.69647396],
#          [ 0.72925013,  0.39058957, -0.13170043, ..., -0.64776117,
#           -0.34552795, -0.41699418]],
#
#         [[ 0.90033334,  0.20104706,  0.13905591, ..., -0.19286804,
#           -0.11133679, -0.9937523 ],
#          [-0.43991131, -0.89230812, -0.32466802, ..., -0.1975159 ,
#           -0.71894854, -0.90491027],
#          [ 0.89898938,  0.51924038, -0.50286359, ..., -0.94317651,
#           -0.34635448,  0.5091418 ]],
#
#         ...,
# ...

# %% [markdown]
# # Generating audio and extracting features
#
# This functionality relies on a few Python sound and speech packages:
#
# - pydub
# - gtts
# - python_speech_features
#
# In case they are not installed, you can use `pip` with the `--user` option to install them in your account. Or clone the package repository and install using `python setup.py develop --user`.

# %% [markdown]
# Read the MEN data

# %%
def read_men():
    records = []
    for line in open("/home/gchrupala/reimaginet/data/MEN/MEN_dataset_natural_form_full"):
        word1, word2, score = line.split()
        records.append((word1, word2, float(score)))
    return records
MEN = read_men()

# %% [markdown]
# Synthesize speech for all the words in MEN

# %%
import imaginet.tts as tts

def synthesize(text):
    return tts.decodemp3(tts.speak(text))

def speak(data):
    voc = set()
    for (w1,w2,_) in data:
        voc.add(w1)
        voc.add(w2)
    voc = list(voc)
    speech = [ synthesize(word) for word in voc ]
    return (voc, speech)

# %%
# Synthesize speech
voc_men, speech_men = speak(MEN)

# %% [markdown]
# Save data for re-use

# %%
import cPickle as pickle
pickle.dump(voc_men, open("/home/gchrupala/reimaginet/data/MEN/voc.pkl","w"),
            protocol=pickle.HIGHEST_PROTOCOL)
pickle.dump(speech_men, open("/home/gchrupala/reimaginet/data/MEN/speech.pkl","w"),
            protocol=pickle.HIGHEST_PROTOCOL)

# %%
voc_men = pickle.load(open("/home/gchrupala/reimaginet/data/MEN/voc.pkl"))
speech_men = pickle.load(open("/home/gchrupala/reimaginet/data/MEN/speech.pkl"))

# %% [markdown]
# Extract MFCC features

# %%
mfcc_men = [ tts.extract_mfcc(audio) for audio in speech_men ]

# %% [markdown]
# Get embeddings by running the model on the extracted features

# %%
embeddings_men = a4.encode_sentences(model_clean, [ numpy.asarray(x, dtype='float32') for x in mfcc_men ])

# %%
from scipy.spatial.distance import cosine
REP = dict(zip(voc_men, embeddings_men))
sim = [ 1-cosine(REP[w1],REP[w2]) for (w1,w2,_) in MEN ]
score = [s for (_,_,s) in MEN]

# %% [markdown]
# Compute Spearman's correlation coefficient between cosine similarities and human scores

# %%
from scipy.stats import spearmanr

# %%
spearmanr(score, sim)
# Out:
# SpearmanrResult(correlation=0.06476500692217102, pvalue=0.0003858549538077964)

# %% [markdown]
# Find nearest neighbors

# %%
from scipy.spatial.distance import cdist
dist_matrix =  cdist(embeddings_men, embeddings_men)

# %%
for i,word in enumerate(voc_men):
    js = numpy.argsort(dist_matrix[i])
    print word, [ voc_men[j] for j in js[1:5] ]
# Out:
# peacock ['hawk', 'boxer', 'sheep', 'house']
# chain ['food', 'jean', 'chicken', 'pink']
# dance ['pigs', 'kiss', 'tickets', 'carrots']
# scratch ['aircraft', 'park', 'stop', 'craft']
# ceramic ['graphic', 'haircut', 'architecture', 'mac']
# yellow ['dome', 'donut', 'dolls', 'mallard']
# sunk ['sun', 'son', 'pets', 'gun']
# protest ['raspberry', 'breakfast', 'friends', 'dress']
# skate ['seat', 'city', 'skin', 'snake']
# sleep ['soup', 'zoo', 'stickers', 'sunk']
# skin ['city', 'seat', 'sushi', 'sketch']
# mill ['milk', 'match', 'metal', 'map']
# children ['jellyfish', 'cathedral', 'angel', 'toes']
# apartment ['diner', 'arch', 'daughter', 'iron']
# gold ['cold', 'home', 'love', 'wolf']
# tv ['tea', 'cute', 'feet', 'seed']
# swan ['flood', 'collage', 'lawn', 'floor']
# bike ['bicycle', 'ipod', 'monument', 'lighting']
# reptiles ['crow', 'craft', 'brown', 'round']
# smile ['flag', 'glass', 'vinyl', 'home']
# dragonfly ['butterfly', 'airplane', 'flag', 'display']
# ...
