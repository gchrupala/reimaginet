# %%
import numpy
import imaginet.task as task

# %% [markdown]
# # Loading models
#
# Load models trained on flickr8k captions (clean and noisy). We'll use the small flickr8k models as an example.

# %%
model_clean = task.load("/home/gchrupala/reimaginet/examples/audioviz/mfcc-flickr8k.zip")
model_noisy = task.load("/home/gchrupala/reimaginet/examples/audioviz/noisy-mfcc-flickr8k.zip")

# %% [markdown]
# # Loading data
#
# Load flickr8k data. This relies on the following files in the reimaginet directory:
# ```
# data/flickr8k/dataset.json
# data/flickr8k/vgg_feats.mat
# data/flickr8k/dataset.mfcc.npy
# data/flickr8k/dataset.noisy.mfcc.npy
# ```

# %%
import imaginet.data_provider as dp

# clean speech
prov_clean = dp.getDataProvider('flickr8k', root='/home/gchrupala/reimaginet', audio_kind='mfcc')
# noisy speech
prov_noisy = dp.getDataProvider('flickr8k', root='/home/gchrupala/reimaginet', audio_kind='noisy.mfcc')
# Out:
# Could not read file /home/gchrupala/reimaginet/data/flickr8k/dataset.ipa.jsonl.gz: IPA transcription not available
# Could not read file /home/gchrupala/reimaginet/data/flickr8k/dataset.ipa.jsonl.gz: IPA transcription not available

# %% [markdown]
# Grab all the validation sentences

# %%
sent_val_clean = list(prov_clean.iterSentences(split='val'))
print sent_val_clean[0]['raw']
print sent_val_clean[0]['audio'].shape
# Out:
# the boy laying face down on a skateboard is being pushed along the ground by another boy .
# (587, 13)

# %% [markdown]
# # Running the model

# %% [markdown]
# Run some sentences through the model and get the sentence embeddings. The function `a4.encode_sentences` is pretty fast as runs audios through the model in batches (to do so it will pad sentences in a batch to the same number of timesteps).

# %%
import imaginet.defn.audiovis4 as a4

data = [ numpy.asarray(sent['audio'], dtype='float32') for sent in sent_val_clean ]
embeddings = a4.encode_sentences(model_clean, data)

# %%
embeddings.shape
# Out:
# (5000, 1024)

# %% [markdown]
# You can also get the intermediate representations (states of hidden layers). Note that for this particular model the states of the top hidden layer at the last timestep are **NOT** equal to the sentence embeddings, as there is an additional attention-like lookback operation to get the final embeddings.
#
# The function `a4.layer_states` is slow because it run each audio through the model one by one, without padding.

# %%
states = a4.layer_states(model_clean, data)

# %%
states[0].shape
# Out:
# (198, 2, 1024)

# %% [markdown]
# The three axes are: (timestep, layer, unit)

# %% [markdown]
# # Generating audio and extracting features
#
# This functionality relies on a few Python sound and speech packages:
#
# - pydub
# - gtts
# - python_speech_features
#
# In case they are not installed, you can use `pip` with the `--user` option to install them in your account. Or clone the package repository and install using `python setup.py develop --user`.

# %% [markdown]
# Read the MEN data

# %%
def read_men():
    records = []
    for line in open("/home/gchrupala/reimaginet/data/MEN/MEN_dataset_natural_form_full"):
        word1, word2, score = line.split()
        records.append((word1, word2, float(score)))
    return records
MEN = read_men()

# %% [markdown]
# Synthesize speech for all the words in MEN

# %%
import imaginet.tts as tts

def synthesize(text):
    return tts.decodemp3(tts.speak(text))

def speak(data):
    voc = set()
    for (w1,w2,_) in data:
        voc.add(w1)
        voc.add(w2)
    voc = list(voc)
    speech = [ synthesize(word) for word in voc ]
    return (voc, speech)

# %%
voc_men, speech_men = speak(MEN)

# %% [markdown]
# Save data for re-use

# %%
numpy.save("/home/gchrupala/reimaginet/data/MEN/voc.npy", voc_men)
numpy.save("/home/gchrupala/reimaginet/data/MEN/speech.npy", speech_men)

# %% [markdown]
# Extract MFCC features

# %%
mfcc_men = [ numpy.log(numpy.exp(1+tts.extract_mfcc(audio))) for audio in speech_men ]

# %% [markdown]
# Get embeddings by running the model on the extracted features

# %%
embeddings_men = a4.encode_sentences(model_clean, [ numpy.asarray(x, dtype='float32') for x in mfcc_men ])

# %%
from scipy.spatial.distance import cosine
REP = dict(zip(voc_men, embeddings_men))
sim = [ 1-cosine(REP[w1],REP[w2]) for (w1,w2,_) in MEN ]
score = [s for (_,_,s) in MEN]

# %% [markdown]
# Compute Spearman's correlation coefficient between cosine similarities and human scores

# %%
from scipy.stats import spearmanr

# %%
spearmanr(score, sim)
# Out:
# SpearmanrResult(correlation=0.050517132235948739, pvalue=0.0056479168911894081)

# %% [markdown]
# Find nearest neighbors

# %%
from scipy.spatial.distance import cdist
dist_matrix =  cdist(embeddings_men, embeddings_men)

# %%
for i,word in enumerate(voc_men):
    js = numpy.argsort(dist_matrix[i])
    print word, [ voc_men[j] for j in js[1:5] ]
# Out:
# peacock ['basket', 'path', 'dusk', 'hot']
# chain ['shade', 'cute', 'pink', 'seed']
# dance ['key', 'beauty', 'knitting', 'daisy']
# scratch ['craft', 'crab', 'track', 'skyline']
# ceramic ['redhead', 'parade', 'brick', 'branch']
# yellow ['lighthouse', 'dawn', 'dog', 'dome']
# sunk ['paws', 'pizza', 'tongue', 'club']
# protest ['friends', 'architecture', 'haircut', 'pets']
# skate ['seed', 'sushi', 'sea', 'daisy']
# sleep ['cute', 'snake', 'police', 'seat']
# skin ['chain', 'bikini', 'kitty', 'sushi']
# mill ['feel', 'metal', 'canal', 'whale']
# children ['television', 'girls', 'illustrations', 'chipmunk']
# apartment ['band', 'head', 'hand', 'garden']
# gold ['cold', 'couple', 'old', 'wolf']
# tv ['daisy', 'kitty', 'bikini', 'sweet']
# swan ['flood', 'pond', 'blonde', 'lunch']
# bike ['light', 'vine', 'flag', 'flight']
# reptiles ['dolls', 'canal', 'petals', 'daffodils']
# smile ['vinyl', 'automobile', 'hill', 'puddle']
# dragonfly ['butterfly', 'rice', 'motorcycle', 'pod']
# garden ['pattern', 'shed', 'berry', 'shirt']
# sitting ['sing', 'city', 'sand', 'snake']
# dessert ['burger', 'mirror', 'lizard', 'curve']
# kitty ['bikini', 'beauty', 'daisy', 'key']
# wave ['ocean', 'wind', 'exhibition', 'sandwich']
# chair ['hair', 'air', 'pier', 'miniature']
# graphic ['track', 'brick', 'branch', 'traffic']
# locked ['hawk', 'clock', 'socks', 'cross']
# monkeys ['beads', 'movie', 'pigs', 'dance']
# chapel ['temple', 'apple', 'cattle', 'dolls']
# tickets ['face', 'shade', 'kiss', 'gate']
# school ['pole', 'wool', 'apple', 'model']
# washing ['wedding', 'white', 'coins', 'lighting']
# parrot ['pin', 'deer', 'gun', 'tea']
# harbor ['harbor', 'art', 'heart', 'arms']
# button ['buds', 'hanging', 'canyon', 'bunny']
# gun ['pin', 'parrot', 'tea', 'deer']
# temple ['chapel', 'bible', 'table', 'apple']
# sand ['stand', 'sunset', 'sunshine', 'sitting']
# race ['pigs', 'cookies', 'police', 'ruins']
# subway ['boys', 'swing', 'highway', 'railway']
# small ['ball', 'gull', 'purple', 'skull']
# poppy ['hockey', 'coffee', 'husky', 'stockings']
# sidewalk ['boardwalk', 'walk', 'wasp', 'relaxed']
# round ['drawn', 'brown', 'underground', 'run']
# clothes ['book', 'club', 'love', 'oak']
# cookies ['pigs', 'goose', 'beads', 'beef']
# bicycle ['motorcycle', 'bike', 'vine', 'light']
# fence ['feathers', 'tag', 'carrots', 'dance']
# collage ['bride', 'leather', 'garage', 'cottage']
# crow ['auto', 'mural', 'marble', 'puddle']
# hanging ['hand', 'bag', 'happy', 'head']
# feathers ['fence', 'jazz', 'goats', 'kiss']
# mural ['metal', 'canal', 'crow', 'bottle']
# jump ['dance', 'lamb', 'dome', 'diamond']
# burger ['curve', 'urban', 'river', 'skirt']
# rusty ['grass', 'restaurant', 'dress', 'raspberry']
# street ['stream', 'scooter', 'stickers', 'poster']
# design ['lighting', 'magazine', 'vine', 'hanging']
# transformers ['sports', 'uniform', 'flowers', 'orchids']
# cactus ['jacket', 'path', 'bath', 'pets']
# port ['porch', 'ford', 'portrait', 'airport']
# creatures ['crane', 'grave', 'grapes', 'portrait']
# blue ['zoo', 'dew', 'ripples', 'couple']
# donut ['note', 'diamond', 'panda', 'match']
# sun ['son', 'fun', 'signed', 'sunk']
# cooking ['dance', 'daisy', 'feet', 'beauty']
# lizard ['shirt', 'parrot', 'nude', 'deer']
# milk ['nails', 'males', 'animals', 'metal']
# illustrations ['cheerleaders', 'toes', 'potatoes', 'fence']
# new ['view', 'musicians', 'lips', 'goose']
# racing ['magazine', 'night', 'nest', 'canyon']
# journal ['tiles', 'cattle', 'pillow', 'petals']
# scenery ['cemetery', 'country', 'cherry', 'sunny']
# toes ['coast', 'clothes', 'goats', 'postcards']
# explosion ['swimsuit', 'necklace', 'motor', 'bracelet']
# leg ['lunch', 'bed', 'highway', 'wine']
# makeup ['idea', 'ship', 'nuts', 'gate']
# water ['underwater', 'waterfall', 'motor', 'wire']
# wild ['tiles', 'pillow', 'puddle', 'petals']
# red ['redhead', 'branch', 'grey', 'bread']
# baseball ['asphalt', 'skull', 'motorcycle', 'tropical']
# sing ['sitting', 'city', 'sea', 'sushi']
# arch ['heart', 'barn', 'card', 'art']
# handle ['candles', 'animals', 'nails', 'beetles']
# kids ['stitches', 'kittens', 'beads', 'pigs']
# daughter ['iris', 'hand', 'pattern', 'duck']
# metro ['arrow', 'copper', 'trail', 'noodles']
# miniature ['nature', 'theatre', 'shirt', 'chair']
# airport ['porch', 'port', 'work', 'door']
# hamster ['monster', 'concert', 'dancers', 'surf']
# smoke ['toes', 'oak', 'clothes', 'cold']
# action ['hand', 'pattern', 'head', 'hat']
# military ['lily', 'village', 'belly', 'note']
# pillow ['cattle', 'dolls', 'bottle', 'puddle']
# glittering ['bridge', 'grey', 'morning', 'red']
# wig ['wind', 'leaf', 'tank', 'boot']
# love ['clothes', 'book', 'web', 'beef']
# apple ['pole', 'couple', 'owl', 'auto']
# family ['highway', 'rally', 'demolition', 'jellyfish']
# motor ['blurred', 'water', 'wire', 'iris']
# duck ['air', 'hair', 'dark', 'chair']
# cloud ['butterfly', 'hot', 'cliff', 'wet']
# sky ['sketch', 'fashion', 'sexy', 'cafe']
# figure ['ear', 'pier', 'sphere', 'deer']
# doodle ['angel', 'hill', 'cattle', 'puddle']
# coins ['toys', 'wedding', 'washing', 'boys']
# dude ['food', 'fish', 'church', 'bench']
# poodle ['metal', 'mill', 'mural', 'canal']
# frog ['rust', 'frost', 'cross', 'rock']
# sports ['flowers', 'forest', 'born', 'horse']
# splash ['display', 'left', 'flight', 'plant']
# music ['vintage', 'gate', 'dude', 'beach']
# crab ['craft', 'scratch', 'card', 'farm']
# vehicle ['couple', 'dew', 'cold', 'view']
# sexy ['sunset', 'taxi', 'seat', 'sunny']
# phone ['clown', 'drawn', 'cloud', 'buds']
# pencil ['vehicle', 'fence', 'ink', 'lips']
# diamond ['man', 'van', 'mug', 'band']
# door ['work', 'floor', 'port', 'jaguar']
# porch ['port', 'airport', 'ford', 'portrait']
# beauty ['tea', 'key', 'kitty', 'nude']
# chocolate ['palace', 'violet', 'wet', 'cliff']
# downtown ['diamond', 'hand', 'phone', 'dance']
# glass ['bus', 'relaxed', 'cliff', 'sunglasses']
# flag ['cloud', 'ipod', 'light', 'flight']
# train ['bright', 'branch', 'bread', 'bridge']
# arms ['farm', 'heart', 'bar', 'art']
# rabbit ['map', 'mac', 'bag', 'bath']
# baby ['candy', 'kitty', 'tv', 'gate']
# circle ['crystal', 'ripples', 'surfers', 'skirt']
# women ['man', 'wind', 'abandoned', 'van']
# town ['web', 'dance', 'happy', 'tag']
# rice ['break', 'horizon', 'rodents', 'dragonfly']
# animals ['handle', 'mammals', 'camel', 'dolls']
# room ['bedroom', 'organ', 'written', 'river']
# salad ['skyline', 'jellyfish', 'chocolate', 'tag']
# tunnel ['marble', 'camel', 'eagle', 'carnival']
# car ['card', 'park', 'fire', 'bar']
# work ['door', 'floor', 'port', 'airport']
# gasoline ['chess', 'gymnastics', 'nest', 'taxi']
# roof ['soup', 'goose', 'ripples', 'view']
# cat ['path', 'shed', 'hat', 'hand']
# soup ['beef', 'goose', 'feet', 'sweet']
# tag ['tank', 'gate', 'tickets', 'pink']
# can ['bed', 'chair', 'miniature', 'shed']
# foliage ['village', 'lady', 'lake', 'lily']
# seagull ['beetles', 'dolls', 'noodles', 'candles']
# marble ['school', 'apple', 'auto', 'couple']
# heart ['art', 'bar', 'arch', 'architecture']
# stream ['street', 'sexy', 'scooter', 'station']
# brown ['round', 'drug', 'rose', 'written']
# skateboard ['keyboard', 'skating', 'door', 'stairs']
# dripping ['pyramid', 'cooking', 'berry', 'dirty']
# autumn ['palm', 'blossom', 'home', 'town']
# sphere ['figure', 'seed', 'pier', 'ear']
# dew ['zoo', 'blue', 'kittens', 'view']
# dropped ['giraffe', 'rock', 'rust', 'traffic']
# pond ['blonde', 'lunch', 'swan', 'pug']
# airplane ['flying', 'escalator', 'sunlight', 'lighting']
# paws ['sunk', 'palace', 'pug', 'club']
# dress ['bus', 'rusty', 'raspberry', 'desk']
# pink ['painting', 'chain', 'vintage', 'cake']
# winter ['dinner', 'air', 'shed', 'bed']
# skirt ['surf', 'surfers', 'burger', 'fruit']
# travel ['canal', 'carnival', 'reptiles', 'traffic']
# club ['palm', 'pub', 'clothes', 'tongue']
# nuts ['kiss', 'lips', 'ship', 'tickets']
# magazine ['mist', 'band', 'diamond', 'mug']
# machine ['vintage', 'cake', 'pink', 'evening']
# lamp ['gymnastics', 'lamb', 'gasoline', 'chess']
# forest ['sports', 'flowers', 'restaurant', 'dress']
# elephant ['vintage', 'ancient', 'monument', 'ink']
# cheetah ['ship', 'jean', 'fish', 'sheep']
# beach ['seat', 'music', 'fish', 'bench']
# pizza ['tickets', 'sheep', 'ship', 'face']
# lamb ['map', 'van', 'match', 'mask']
# plant ['cliff', 'flood', 'wet', 'color']
# sandwich ['sand', 'texture', 'snake', 'sunset']
# cocktail ['car', 'craft', 'track', 'card']
# farm ['arms', 'bar', 'crab', 'parking']
# stop ['hot', 'shop', 'pets', 'socks']
# swing ['subway', 'swim', 'wedding', 'washing']
# collection ['collage', 'flag', 'sunlight', 'display']
# mac ['map', 'match', 'panda', 'mask']
# plane ['holiday', 'plant', 'flood', 'line']
# lighting ['vine', 'lion', 'wine', 'bucket']
# hawk ['clock', 'locked', 'socks', 'hot']
# bloom ['home', 'palm', 'pub', 'autumn']
# man ['van', 'mug', 'mist', 'engine']
# tomato ['arrow', 'males', 'patio', 'piano']
# light ['bike', 'vine', 'flight', 'fungi']
# fungi ['idea', 'light', 'mac', 'guy']
# dragon ['bread', 'friends', 'pregnant', 'horizon']
# tulip ['clothes', 'love', 'coast', 'toes']
# shore ['texture', 'mirror', 'nature', 'air']
# truck ['art', 'park', 'breakfast', 'heart']
# shade ['chain', 'eat', 'seed', 'kitty']
# necklace ['locomotives', 'explosion', 'note', 'sunlight']
# tall ['wall', 'ball', 'owl', 'skull']
# wing ['living', 'licking', 'rain', 'wind']
# wind ['wig', 'women', 'wing', 'man']
# wine ['cone', 'outfit', 'lion', 'can']
# cute ['feet', 'eat', 'weed', 'key']
# played ['lake', 'sunlight', 'airplane', 'crane']
# shoes ['goose', 'kittens', 'musicians', 'pigeon']
# office ['kiss', 'pigs', 'nuts', 'tongue']
# pelican ['neon', 'pumpkin', 'cone', 'clown']
# haircut ['bed', 'ad', 'air', 'hand']
# cross ['frost', 'rust', 'locked', 'rock']
# held ['petals', 'cold', 'model', 'apple']
# mallard ['diner', 'bag', 'outfit', 'rabbit']
# paper ['burger', 'river', 'curve', 'urban']
# motorcycle ['bicycle', 'dragonfly', 'bike', 'baseball']
# keyboard ['ford', 'port', 'morning', 'door']
# cold ['gold', 'old', 'couple', 'muscle']
# birds ['burger', 'fruit', 'curve', 'urban']
# underwater ['water', 'waterfall', 'weather', 'motor']
# police ['leaf', 'sweet', 'pigs', 'beads']
# cheerleaders ['feathers', 'amphibians', 'stitches', 'tears']
# hot ['hawk', 'hat', 'path', 'stop']
# window ['windmill', 'flamingo', 'metal', 'males']
# redhead ['branch', 'red', 'graphic', 'grey']
# holiday ['plane', 'lake', 'bucket', 'plant']
# dolls ['petals', 'beetles', 'pillow', 'cattle']
# toys ['boys', 'coins', 'twigs', 'sports']
# coffee ['hockey', 'poppy', 'husky', 'stockings']
# evening ['tank', 'knitting', 'day', 'vintage']
# food ['dude', 'boot', 'church', 'cute']
# auto ['shadow', 'apple', 'cattle', 'bottle']
# males ['nails', 'mammals', 'metal', 'animals']
# trail ['rail', 'pillow', 'cattle', 'shell']
# break ['bright', 'parade', 'grey', 'brick']
# lunch ['lion', 'flood', 'pond', 'lantern']
# giraffe ['dropped', 'rock', 'craft', 'rust']
# snake ['painted', 'vintage', 'seed', 'stand']
# kiss ['face', 'tickets', 'pets', 'jazz']
# gate ['eat', 'cute', 'shade', 'feet']
# jaguar ['door', 'floor', 'tower', 'work']
# bath ['badge', 'jacket', 'path', 'cat']
# silver ['river', 'burger', 'paper', 'furniture']
# bread ['dragon', 'furniture', 'friends', 'branch']
# meat ['cake', 'movie', 'gate', 'misty']
# pregnant ['friends', 'party', 'garden', 'bread']
# tram ['scratch', 'branch', 'track', 'frame']
# potatoes ['tickets', 'goats', 'feathers', 'kiss']
# swimsuit ['explosion', 'swim', 'crystal', 'lens']
# lingerie ['arch', 'scratch', 'collage', 'break']
# arrow ['auto', 'shadow', 'canal', 'tomato']
# rock ['rust', 'dropped', 'giraffe', 'cross']
# lantern ['bed', 'pyramid', 'dirt', 'lunch']
# square ['aquarium', 'wire', 'footprint', 'fireworks']
# map ['match', 'mac', 'mask', 'panda']
# house ['socks', 'moss', 'palm', 'clock']
# fish ['ship', 'head', 'bench', 'dude']
# idea ['makeup', 'guy', 'cheetah', 'ship']
# goose ['shoes', 'kittens', 'soup', 'beef']
# zebra ['rock', 'dropped', 'giraffe', 'rust']
# cathedral ['mural', 'feel', 'angel', 'journal']
# dawn ['dog', 'yellow', 'donut', 'mallard']
# bay ['day', 'jacket', 'night', 'mist']
# terrier ['pyramid', 'beer', 'dead', 'dinner']
# sunrise ['stripes', 'carrots', 'friends', 'frame']
# living ['wing', 'licking', 'museum', 'painting']
# staircase ['stairs', 'stickers', 'sexy', 'stripes']
# pigeon ['chain', 'shade', 'knitting', 'beads']
# fountain ['town', 'sunshine', 'sunk', 'fence']
# hill ['angel', 'peel', 'feel', 'doodle']
# highway ['alley', 'belly', 'railway', 'bunny']
# eagle ['school', 'daffodils', 'handle', 'vehicle']
# umbrella ['cross', 'relaxed', 'frost', 'rust']
# monster ['hamster', 'whiskers', 'dancers', 'concert']
# dirt ['ear', 'boot', 'church', 'shirt']
# ipod ['cloud', 'butterfly', 'outfit', 'vine']
# pug ['club', 'buds', 'blonde', 'clothes']
# pub ['club', 'tongue', 'palm', 'clothes']
# stencil ['statue', 'piano', 'sand', 'stand']
# lab ['club', 'pug', 'frog', 'buds']
# grapes ['grave', 'bright', 'bridge', 'grey']
# weed ['key', 'cute', 'beauty', 'feet']
# cattle ['bottle', 'puddle', 'shadow', 'pillow']
# guy ['dye', 'bag', 'ad', 'day']
# card ['iris', 'car', 'fire', 'arch']
# carnival ['travel', 'spiral', 'tunnel', 'marble']
# punk ['eggs', 'love', 'beef', 'outfit']
# festival ['bible', 'tropical', 'castle', 'chapel']
# musicians ['shoes', 'pigs', 'kittens', 'beads']
# daisy ['bikini', 'kitty', 'sushi', 'sea']
# castle ['asphalt', 'travel', 'skull', 'petals']
# orchids ['work', 'portrait', 'horse', 'sports']
# copper ['cross', 'rock', 'rust', 'harbour']
# industrial ['street', 'trail', 'abstract', 'metal']
# advertisement ['diner', 'haircut', 'basket', 'band']
# feel ['peel', 'angel', 'hill', 'show']
# wasp ['walk', 'boardwalk', 'relaxed', 'moss']
# number ['river', 'urban', 'pepper', 'breakfast']
# valentine ['bag', 'match', 'hand', 'diner']
# feet ['eat', 'cute', 'key', 'tea']
# chopper ['copper', 'fence', 'construction', 'summer']
# mist ['nest', 'van', 'mug', 'man']
# maple ['statue', 'people', 'ripples', 'pencil']
# sheep ['eat', 'pizza', 'ship', 'cheetah']
# city ['sea', 'sushi', 'seed', 'sing']
# horse ['flowers', 'sports', 'rusty', 'arms']
# ancient ['pink', 'ink', 'vintage', 'tank']
# lego ['show', 'feel', 'canal', 'whale']
# blossom ['palm', 'moss', 'pub', 'mom']
# automobile ['peel', 'hill', 'feel', 'angel']
# girls ['petals', 'squirrel', 'curled', 'dolls']
# ripples ['roof', 'blue', 'dew', 'circle']
# stork ['store', 'tower', 'outdoor', 'portrait']
# station ['skate', 'stand', 'seed', 'sea']
# storm ['stork', 'spiral', 'chopper', 'farm']
# tea ['key', 'beauty', 'pin', 'deer']
# white ['railway', 'wedding', 'break', 'leg']
# jellyfish ['village', 'valley', 'salad', 'silhouette']
# banana ['cat', 'ship', 'jacket', 'cheetah']
# store ['stork', 'portrait', 'sunflower', 'summer']
# beard ['shirt', 'pyramid', 'deer', 'ear']
# urban ['river', 'curve', 'burger', 'breakfast']
# eyes ['ice', 'eggs', 'pigs', 'tag']
# shell ['cattle', 'canal', 'shadow', 'pillow']
# bacon ['vacation', 'pigs', 'pink', 'chain']
# hotel ['fell', 'puddle', 'petals', 'cattle']
# park ['car', 'truck', 'bar', 'heart']
# poster ['monster', 'street', 'stairs', 'stickers']
# vinyl ['smile', 'tropical', 'clock', 'hot']
# postcards ['coast', 'toes', 'book', 'goats']
# flowers ['sports', 'horse', 'forest', 'born']
# stairs ['staircase', 'stickers', 'sphere', 'stand']
# steel ['snow', 'feel', 'peel', 'show']
# television ['shopping', 'painting', 'ancient', 'kids']
# sailing ['ceiling', 'snowman', 'skating', 'stencil']
# tree ['country', 'dirty', 'berry', 'beef']
# grey ['branch', 'bridge', 'bright', 'grapes']
# bed ['shed', 'can', 'band', 'ad']
# panda ['mac', 'match', 'jacket', 'map']
# bride ['garage', 'collage', 'cottage', 'drive']
# computer ['terrier', 'beer', 'food', 'theatre']
# flame ['flying', 'time', 'vine', 'ipod']
# iron ['iris', 'card', 'hand', 'diner']
# candles ['noodles', 'handle', 'dolls', 'tiles']
# sculpture ['picture', 'winter', 'texture', 'poster']
# bridge ['bright', 'grey', 'grapes', 'branch']
# fashion ['hand', 'head', 'hat', 'pattern']
# palace ['chocolate', 'paws', 'violet', 'house']
# chipmunk ['club', 'kids', 'sunk', 'tongue']
# parking ['art', 'heart', 'truck', 'bar']
# ceiling ['skating', 'pink', 'machine', 'skate']
# alley ['belly', 'highway', 'happy', 'idea']
# seed ['sushi', 'sea', 'feet', 'daisy']
# graffiti ['birthday', 'ski', 'sweet', 'seed']
# origami ['farm', 'bar', 'arms', 'portrait']
# breakfast ['art', 'urban', 'curve', 'crochet']
# mountain ['mud', 'button', 'buds', 'phone']
# silhouette ['jellyfish', 'salad', 'sandwich', 'highway']
# escalator ['airplane', 'bucket', 'guitar', 'mother']
# person ['curve', 'frozen', 'burger', 'fruit']
# snow ['steel', 'snowman', 'hill', 'doodle']
# zoo ['dew', 'view', 'blue', 'soup']
# note ['mac', 'donut', 'ocean', 'match']
# chess ['pets', 'jacket', 'jazz', 'nest']
# rodents ['road', 'railroad', 'rice', 'parade']
# mammals ['males', 'animals', 'camel', 'daffodils']
# interior ['tiger', 'sphere', 'figure', 'ear']
# green ['hummingbird', 'paper', 'organ', 'burn']
# lily ['belly', 'military', 'lady', 'village']
# butterfly ['cloud', 'dragonfly', 'ipod', 'hot']
# fireworks ['fire', 'iris', 'car', 'park']
# theatre ['pier', 'shirt', 'miniature', 'beer']
# track ['traffic', 'graphic', 'hat', 'craft']
# quote ['old', 'pole', 'oak', 'gold']
# eggs ['eyes', 'bag', 'head', 'ice']
# object ['nest', 'badge', 'tank', 'mist']
# cigarette ['theatre', 'furniture', 'air', 'church']
# moss ['house', 'mom', 'clock', 'socks']
# crochet ['fruit', 'curve', 'furniture', 'burger']
# model ['owl', 'gull', 'ball', 'petals']
# grave ['grapes', 'bright', 'bridge', 'grey']
# lawn ['blonde', 'flood', 'line', 'pub']
# clock ['hawk', 'locked', 'socks', 'hot']
# metal ['bottle', 'canal', 'cattle', 'mill']
# dog ['dawn', 'dark', 'peacock', 'yellow']
# face ['kiss', 'tickets', 'shade', 'pigs']
# sunset ['sand', 'sexy', 'sunshine', 'stand']
# patio ['auto', 'piano', 'show', 'aerial']
# pattern ['fabric', 'hand', 'head', 'action']
# stockings ['coffee', 'poppy', 'hockey', 'husky']
# painting ['pink', 'game', 'bacon', 'stitches']
# shop ['hot', 'locked', 'cat', 'pets']
# taxi ['ski', 'misty', 'sea', 'bikini']
# asphalt ['castle', 'office', 'tropical', 'colorful']
# show ['peel', 'angel', 'feel', 'shell']
# insects ['carrots', 'texture', 'exhibition', 'fence']
# bright ['grapes', 'grave', 'bridge', 'parade']
# bedroom ['band', 'garden', 'dripping', 'friends']
# soldiers ['postcards', 'tears', 'cold', 'stickers']
# chicken ['chain', 'painted', 'pigeon', 'shade']
# uniform ['transformers', 'people', 'farm', 'table']
# crane ['crochet', 'grapes', 'bright', 'grave']
# curled ['cold', 'gold', 'girls', 'old']
# scooter ['skirt', 'street', 'surfers', 'stickers']
# gull ['ball', 'owl', 'model', 'small']
# mug ['mist', 'man', 'band', 'nest']
# texture ['theatre', 'church', 'shirt', 'chair']
# bakery ['pyramid', 'meat', 'face', 'night']
# tears ['kittens', 'pigs', 'stitches', 'beads']
# wood ['weather', 'wet', 'flood', 'dinner']
# black ['left', 'relaxed', 'craft', 'track']
# hockey ['coffee', 'husky', 'poppy', 'ski']
# piano ['animals', 'handle', 'patio', 'statue']
# wool ['wolf', 'gull', 'ball', 'owl']
# drug ['friends', 'underground', 'brown', 'action']
# pumpkin ['kitchen', 'neon', 'engine', 'can']
# tiles ['petals', 'dolls', 'cold', 'puddle']
# sunglasses ['bus', 'glass', 'relaxed', 'photos']
# rose ['brown', 'coast', 'drug', 'toes']
# colorful ['muscle', 'spiral', 'asphalt', 'tropical']
# dandelion ['demolition', 'aerial', 'camel', 'skyline']
# photography ['photographer', 'downtown', 'paws', 'phone']
# jazz ['kiss', 'pets', 'chess', 'feathers']
# sunny ['city', 'sand', 'party', 'sexy']
# stripes ['carrots', 'party', 'stickers', 'staircase']
# coast ['toes', 'oak', 'clothes', 'book']
# words ['ruins', 'born', 'ripples', 'birds']
# wedding ['white', 'washing', 'coins', 'licking']
# dye ['guy', 'bag', 'bath', 'cat']
# beads ['kittens', 'tv', 'pigeon', 'pigs']
# bar ['heart', 'art', 'car', 'park']
# organ ['burn', 'urban', 'portrait', 'river']
# leather ['weather', 'color', 'colour', 'collage']
# badge ['bath', 'jacket', 'shed', 'parrot']
# licking ['living', 'wing', 'painting', 'shopping']
# morning ['glittering', 'keyboard', 'born', 'wedding']
# bag ['hand', 'ad', 'head', 'hanging']
# skyline ['scratch', 'fashion', 'stop', 'hot']
# architecture ['art', 'heart', 'hair', 'air']
# frame ['furniture', 'crane', 'tram', 'friends']
# river ['urban', 'curve', 'burger', 'person']
# ruins ['words', 'rope', 'beads', 'kittens']
# view ['zoo', 'soup', 'dew', 'pigeon']
# body ['bunny', 'ivy', 'happy', 'puppy']
# art ['heart', 'architecture', 'parking', 'breakfast']
# concert ['surfers', 'surf', 'skirt', 'hamster']
# puddle ['cattle', 'bottle', 'petals', 'hotel']
# vine ['flight', 'light', 'lighting', 'bike']
# canine ['bench', 'can', 'bed', 'head']
# blurred ['motor', 'burger', 'bridge', 'burn']
# lion
#  ['line', 'lunch', 'wine', 'mud']
# daffodils ['noodles', 'nails', 'beetles', 'handle']
# sea ['sushi', 'seed', 'ski', 'daisy']
# violet ['cliff', 'chocolate', 'palace', 'plant']
# portrait ['burn', 'crochet', 'bright', 'art']
# noodles ['candles', 'daffodils', 'dolls', 'beetles']
# barn ['arch', 'heart', 'iris', 'bar']
# pebbles ['dolls', 'house', 'school', 'petals']
# wire ['fire', 'iris', 'craft', 'barn']
# crystal ['purple', 'gull', 'wolf', 'small']
# movie ['daisy', 'eat', 'tv', 'kitty']
# feline ['skyline', 'cottage', 'flight', 'collage']
# mud ['buds', 'mountain', 'lens', 'lion']
# written ['garden', 'moon', 'frozen', 'brown']
# skyscraper ['skirt', 'surf', 'surfers', 'scooter']
# pets ['path', 'chess', 'desk', 'kiss']
# drawn ['drive', 'droplets', 'phone', 'frog']
# reading ['knitting', 'candy', 'tree', 'tank']
# gravestone ['stone', 'sunset', 'donut', 'downtown']
# nature ['miniature', 'chair', 'ear', 'mirror']
# dome ['dolls', 'mom', 'aerial', 'palm']
# outfit ['head', 'hand', 'bag', 'ad']
# guitar ['daughter', 'iris', 'peacock', 'car']
# aircraft ['craft', 'car', 'crab', 'park']
# aquarium ['square', 'swim', 'spring', 'ford']
# key ['tea', 'beauty', 'eat', 'feet']
# market ['art', 'burn', 'portrait', 'protest']
# kitchen ['engine', 'can', 'jean', 'miniature']
# cop ['office', 'pod', 'hawk', 'tongue']
# cow ['cattle', 'pillow', 'owl', 'bottle']
# restaurant ['raspberry', 'rusty', 'dress', 'grass']
# country ['tree', 'dirty', 'berry', 'cemetery']
# waterfall ['water', 'underwater', 'rust', 'rock']
# berry ['shirt', 'lizard', 'shed', 'boot']
# cherry ['bikini', 'baby', 'daisy', 'candy']
# railway ['rally', 'highway', 'white', 'family']
# color ['colour', 'collar', 'plant', 'leather']
# sweet ['tv', 'seed', 'feet', 'chain']
# harbour ['harbor', 'art', 'heart', 'arms']
# walk ['wasp', 'boardwalk', 'sidewalk', 'relaxed']
# canyon ['dance', 'tank', 'day', 'man']
# village ['jellyfish', 'belly', 'bench', 'lunch']
# pregnancy ['pregnant', 'sunny', 'city', 'cemetery']
# table ['temple', 'people', 'couple', 'bible']
# blonde ['pond', 'pug', 'lawn', 'lunch']
# bench ['fish', 'can', 'head', 'dude']
# goats ['goose', 'nuts', 'kittens', 'feathers']
# boat ['arch', 'parking', 'craft', 'cloud']
# bathroom ['pepper', 'curve', 'breakfast', 'decoration']
# angel ['peel', 'hill', 'feel', 'show']
# beef ['eat', 'key', 'feet', 'tea']
# bible ['temple', 'marble', 'festival', 'auto']
# vacation ['bacon', 'pigeon', 'chain', 'pink']
# tropical ['house', 'vinyl', 'asphalt', 'palm']
# beer ['pier', 'deer', 'hair', 'ear']
# stadium ['skin', 'skating', 'statue', 'painting']
# brick ['bridge', 'branch', 'bright', 'grey']
# engine ['can', 'man', 'miniature', 'boot']
# field ['soup', 'skull', 'tall', 'small']
# carrots ['stripes', 'fence', 'pets', 'chess']
# shopping ['licking', 'painting', 'fountain', 'wing']
# squirrel ['girls', 'school', 'mural', 'marble']
# graveyard ['round', 'drawn', 'blonde', 'rope']
# painted ['vintage', 'shade', 'gate', 'chain']
# droplets ['hot', 'drawn', 'hat', 'stop']
# sunshine ['stand', 'sand', 'signed', 'sunset']
# amphibians ['feathers', 'fence', 'canyon', 'musicians']
# tiger ['interior', 'figure', 'sphere', 'pier']
# orange ['swan', 'born', 'airport', 'lunch']
# craft ['crab', 'track', 'giraffe', 'traffic']
# mannequin ['abandoned', 'mist', 'van', 'band']
# smoking ['vehicle', 'zoo', 'leaf', 'chain']
# locomotives ['necklace', 'mountain', 'motor', 'butterfly']
# tank ['ink', 'vintage', 'gate', 'dead']
# abandoned ['mannequin', 'man', 'mist', 'van']
# frozen ['person', 'fruit', 'curve', 'roof']
# ski ['sea', 'sushi', 'seed', 'daisy']
# twigs ['toys', 'carrots', 'kittens', 'eyes']
# air ['hair', 'chair', 'pier', 'haircut']
# rope ['old', 'purple', 'held', 'wolf']
# bikini ['kitty', 'daisy', 'sushi', 'beauty']
# fun ['time', 'skin', 'fence', 'action']
# handwriting ['band', 'redhead', 'bedroom', 'red']
# spider ['fireworks', 'tiger', 'design', 'sunlight']
# canal ['metal', 'shell', 'cattle', 'mill']
# pyramid ['beard', 'shirt', 'terrier', 'boot']
# beetles ['dolls', 'petals', 'nails', 'daffodils']
# sushi ['sea', 'seed', 'ski', 'daisy']
# decoration ['pepper', 'bathroom', 'dessert', 'burger']
# cone ['wine', 'neon', 'outfit', 'alley']
# rally ['railway', 'family', 'lady', 'highway']
# demolition ['family', 'village', 'dandelion', 'jellyfish']
# ivy ['baby', 'puppy', 'movie', 'misty']
# tattoo ['game', 'kids', 'beads', 'tears']
# memorial ['rail', 'mural', 'lego', 'rainbow']
# shirt ['church', 'parrot', 'boot', 'shed']
# vintage ['painted', 'tank', 'pink', 'shade']
# pigs ['ink', 'tickets', 'beads', 'bacon']
# belly ['alley', 'lily', 'bench', 'makeup']
# underground ['drawn', 'architecture', 'drug', 'friends']
# party ['stripes', 'pregnant', 'crochet', 'fruit']
# stickers ['skirt', 'fruit', 'stairs', 'sphere']
# bunny ['body', 'ivy', 'outfit', 'happy']
# windmill ['window', 'canal', 'metal', 'males']
# ball ['gull', 'owl', 'wall', 'small']
# knitting ['nude', 'beauty', 'key', 'bikini']
# dusk ['mask', 'desk', 'basket', 'map']
# nest ['mist', 'day', 'desk', 'kiss']
# rail ['trail', 'mural', 'crow', 'memorial']
# rain ['van', 'man', 'meat', 'night']
# hand ['hanging', 'hat', 'bag', 'head']
# fruit ['crochet', 'curve', 'skirt', 'pepper']
# statue ['maple', 'piano', 'stencil', 'daffodils']
# footprint ['crane', 'park', 'crochet', 'party']
# whale ['aerial', 'mill', 'peel', 'feel']
# collar ['colour', 'color', 'car', 'park']
# hummingbird ['bridge', 'burger', 'paper', 'library']
# reflection ['bike', 'light', 'mushrooms', 'vine']
# band ['bed', 'badge', 'mist', 'ad']
# colour ['color', 'collar', 'plant', 'tower']
# ocean ['exhibition', 'shoes', 'engine', 'wave']
# concrete ['hummingbird', 'bathroom', 'chopper', 'concert']
# bottle ['cattle', 'metal', 'puddle', 'dolls']
# mother ['architecture', 'hair', 'daughter', 'air']
# jean ['tea', 'key', 'beauty', 'deer']
# muscle ['mom', 'cold', 'small', 'model']
# left ['black', 'splash', 'relaxed', 'color']
# snowman ['snow', 'stone', 'steel', 'station']
# summer ['harbor', 'harbour', 'tower', 'store']
# outdoor ['stork', 'tower', 'store', 'mirror']
# rocket ['rust', 'rock', 'giraffe', 'craft']
# camel ['animals', 'canal', 'mammals', 'handle']
# boot ['shirt', 'beef', 'eat', 'key']
# dancers ['hamster', 'monster', 'concert', 'stairs']
# neon ['cone', 'web', 'can', 'pumpkin']
# birthday ['graffiti', 'pregnancy', 'cemetery', 'protest']
# fishing ['beach', 'kitchen', 'new', 'music']
# railroad ['road', 'rodents', 'underground', 'glittering']
# web ['wet', 'love', 'pizza', 'idea']
# sunflower ['store', 'tower', 'flowers', 'stork']
# flood ['plant', 'lunch', 'swan', 'lawn']
# photographer ['photography', 'dog', 'dawn', 'camera']
# lighthouse ['light', 'yellow', 'vinyl', 'bucket']
# cemetery ['country', 'cherry', 'scenery', 'sunny']
# lake ['played', 'holiday', 'plane', 'lady']
# day ['dead', 'bay', 'tank', 'jacket']
# wall ['ball', 'tall', 'wolf', 'skull']
# exhibition ['engine', 'shoes', 'ocean', 'snake']
# wet ['web', 'cat', 'cliff', 'bucket']
# hat ['hand', 'path', 'bag', 'hot']
# match ['map', 'mac', 'panda', 'mist']
# swim ['aquarium', 'swing', 'swimsuit', 'ceiling']
# couple ['pole', 'apple', 'cold', 'gold']
# dark ['duck', 'star', 'tower', 'architecture']
# game ['painting', 'tattoo', 'bacon', 'kids']
# boxer ['concert', 'surfers', 'hamster', 'surf']
# traffic ['track', 'craft', 'hat', 'truck']
# mom ['ball', 'muscle', 'oak', 'tall']
# desk ['basket', 'pets', 'nest', 'bath']
# shadow ['cattle', 'auto', 'shell', 'apple']
# lady ['wig', 'foliage', 'lily', 'lake']
# furniture ['crochet', 'fruit', 'pepper', 'art']
# flamingo ['window', 'lego', 'steel', 'windmill']
# nude ['beauty', 'pin', 'key', 'tea']
# bracelet ['cliff', 'plant', 'lake', 'color']
# pole ['apple', 'couple', 'wolf', 'wool']
# candy ['bikini', 'baby', 'kitty', 'daisy']
# garage ['bride', 'drive', 'collage', 'horizon']
# night ['bay', 'day', 'nest', 'jacket']
# tower ['bar', 'art', 'heart', 'stork']
# surf ['surfers', 'skirt', 'concert', 'burger']
# sketch ['fish', 'seat', 'music', 'texture']
# old ['purple', 'ball', 'cold', 'wolf']
# parade ['bright', 'branch', 'grey', 'bridge']
# people ['table', 'blue', 'dew', 'maple']
# spring ['crane', 'creatures', 'frame', 'grave']
# church ['shirt', 'shed', 'theatre', 'miniature']
# basket ['desk', 'cactus', 'bath', 'jacket']
# dead ['shed', 'day', 'dinner', 'bed']
# hair ['air', 'chair', 'beer', 'pier']
# born ['sports', 'flowers', 'orchids', 'words']
# lips ['nuts', 'goose', 'goats', 'office']
# palm ['club', 'tongue', 'house', 'pub']
# clown ['club', 'pug', 'plant', 'web']
# mirror ['ear', 'shirt', 'nature', 'miniature']
# home ['mom', 'cop', 'oak', 'held']
# pod ['cop', 'cloud', 'office', 'cafe']
# leaf ['beef', 'eat', 'gate', 'vintage']
# jewelry ['born', 'keyboard', 'break', 'orange']
# purple ['ball', 'old', 'gull', 'small']
# path ['cat', 'hat', 'pets', 'bath']
# ice ['eyes', 'eggs', 'face', 'kiss']
# moon ['dirt', 'written', 'leaf', 'lantern']
# fog ['cloud', 'butterfly', 'clown', 'pod']
# landscape ['rabbit', 'eggs', 'rice', 'makeup']
# christmas ['face', 'sunk', 'photos', 'design']
# pepper ['curve', 'fruit', 'crochet', 'person']
# run ['brown', 'frog', 'bride', 'round']
# peel ['feel', 'angel', 'hill', 'show']
# nails ['males', 'beetles', 'daffodils', 'milk']
# burn ['portrait', 'bridge', 'bright', 'birds']
# costumes ['fountain', 'pizza', 'stitches', 'jazz']
# zombie ['cake', 'meat', 'misty', 'pink']
# step ['ship', 'santa', 'pizza', 'fish']
# santa ['step', 'shop', 'cheetah', 'ship']
# raspberry ['restaurant', 'dress', 'rusty', 'protest']
# iris ['card', 'fire', 'iron', 'barn']
# stone ['gravestone', 'snowman', 'donut', 'snow']
# diner ['bag', 'iron', 'air', 'haircut']
# petals ['dolls', 'model', 'owl', 'tiles']
# surfers ['surf', 'skirt', 'concert', 'whiskers']
# dinner ['parrot', 'deer', 'dead', 'shed']
# wolf ['ball', 'wool', 'gull', 'small']
# stand ['sand', 'sunshine', 'seat', 'city']
# horizon ['drive', 'bride', 'dragon', 'rice']
# tongue ['palm', 'pub', 'club', 'office']
# road ['rodents', 'railroad', 'brick', 'bridge']
# swimming ['women', 'abandoned', 'rain', 'building']
# owl ['ball', 'gull', 'model', 'tall']
# garbage ['tank', 'shed', 'bed', 'shirt']
# shed ['shirt', 'bed', 'dead', 'parrot']
# socks ['hawk', 'locked', 'clock', 'pets']
# son ['sun', 'fun', 'signed', 'sunshine']
# mushrooms ['mud', 'flood', 'cliff', 'button']
# weather ['leather', 'wood', 'hair', 'wet']
# female ['cattle', 'pillow', 'puddle', 'fell']
# stitches ['kittens', 'kids', 'beads', 'pigs']
# buds ['mud', 'button', 'pug', 'mountain']
# van ['mist', 'man', 'bay', 'diamond']
# fabric ['pattern', 'haircut', 'head', 'air']
# panorama ['tram', 'caterpillars', 'lamb', 'sunrise']
# museum ['living', 'bacon', 'painting', 'licking']
# flying ['flame', 'airplane', 'lighting', 'vine']
# spiral ['crab', 'barn', 'bar', 'carnival']
# sunlight ['airplane', 'played', 'flight', 'flying']
# camera ['pumpkin', 'drawn', 'rock', 'web']
# caterpillars ['advertisement', 'fabric', 'stop', 'illustrations']
# valley ['jellyfish', 'belly', 'village', 'highway']
# happy ['hanging', 'hand', 'cafe', 'outfit']
# head ['hand', 'bag', 'outfit', 'shed']
# kittens ['beads', 'shoes', 'stitches', 'goose']
# bus ['glass', 'relaxed', 'socks', 'hawk']
# relaxed ['bus', 'glass', 'cross', 'locked']
# frost ['cross', 'rust', 'rock', 'frog']
# ford ['port', 'porch', 'portrait', 'floor']
# boys ['toys', 'subway', 'coins', 'twigs']
# construction ['garden', 'frozen', 'chicken', 'dirty']
# library ['bridge', 'grey', 'bright', 'grapes']
# cottage ['fire', 'card', 'iris', 'bride']
# line ['lion', 'love', 'web', 'button']
# ear ['beer', 'pier', 'shirt', 'theatre']
# eat ['feet', 'key', 'beef', 'gate']
# posted ['clothes', 'love', 'sunk', 'sushi']
# misty ['movie', 'ski', 'sea', 'meat']
# skull ['tall', 'ball', 'small', 'gull']
# bucket ['wet', 'outfit', 'haircut', 'bay']
# signed ['sunshine', 'stand', 'tank', 'ink']
# strawberry ['scratch', 'stripes', 'party', 'parade']
# dirty ['tree', 'cherry', 'country', 'movie']
# monument ['ink', 'vacation', 'bacon', 'elephant']
# cake ['meat', 'pink', 'baby', 'vintage']
# gymnastics ['gasoline', 'chess', 'mask', 'nest']
# grass ['rusty', 'restaurant', 'cross', 'rust']
# display ['flight', 'splash', 'plant', 'pod']
# rust ['rock', 'cross', 'frost', 'giraffe']
# skating ['skate', 'sing', 'city', 'sitting']
# aerial ['whale', 'peel', 'mill', 'feel']
# ad ['bag', 'head', 'hand', 'bed']
# pin ['parrot', 'gun', 'tea', 'deer']
# mask ['map', 'mac', 'dusk', 'desk']
# abstract ['track', 'hamster', 'graphic', 'card']
# deer ['pier', 'pin', 'parrot', 'tea']
# drive ['horizon', 'dropped', 'iris', 'garage']
# boardwalk ['sidewalk', 'walk', 'wasp', 'black']
# ink ['beef', 'tank', 'knitting', 'nude']
# flight ['display', 'vine', 'light', 'splash']
# ship ['gate', 'fish', 'eat', 'tickets']
# cafe ['jacket', 'head', 'happy', 'cactus']
# rainbow ['aerial', 'whale', 'lego', 'canal']
# floor ['door', 'work', 'tower', 'jaguar']
# oak ['mom', 'beef', 'soup', 'cold']
# fire ['iris', 'card', 'car', 'wire']
# book ['clothes', 'love', 'oak', 'locked']
# branch ['grey', 'bridge', 'bright', 'redhead']
# puppy ['baby', 'ivy', 'tv', 'kitty']
# pier ['deer', 'beer', 'theatre', 'parrot']
# picture ['church', 'architecture', 'fish', 'chair']
# star ['dark', 'car', 'guitar', 'tower']
# whiskers ['surfers', 'monster', 'scooter', 'surf']
# lens ['mud', 'buds', 'lunch', 'button']
# fell ['owl', 'petals', 'hotel', 'model']
# friends ['pregnant', 'garden', 'bread', 'protest']
# desert ['fish', 'beach', 'music', 'fashion']
# pool ['wool', 'purple', 'gull', 'wolf']
# cliff ['plant', 'wet', 'violet', 'cloud']
# building ['mannequin', 'abandoned', 'swimming', 'licking']
# photos ['sunk', 'paws', 'feathers', 'sunglasses']
# curve ['burger', 'urban', 'river', 'person']
# jacket ['cactus', 'bay', 'badge', 'bath']
# seat ['seed', 'city', 'stand', 'sweet']
# time ['hanging', 'fun', 'hand', 'fashion']
# husky ['hockey', 'coffee', 'poppy', 'ski']
