# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from ggplot import *
import pandas as pd

# %%
data = pd.DataFrame(
    dict(epoch=range(1,8)+range(1,11)+range(1,11),
         recall=[0.160015993603,
                 0.184406237505,
                 0.193202718912,
                 0.19956017593,
                 0.201079568173,
                 0.201719312275,
                 0.19944022391,
                 0.16093562575, 
                 0.185525789684,
                 0.194482207117,
                 0.202758896441,
                 0.203558576569,
                 0.20243902439,
                 0.199240303878,
                 0.195361855258,
                 0.193242702919,
                 0.189924030388,
                 0.137984806078,
                 0.145581767293,
                 0.149340263894,
                 0.151819272291,
                 0.152898840464,
                 0.154218312675,
                 0.155257896841,
                 0.155697720912,
                 0.15637744902,
                 0.156657337065
            ],
         model=hstack([repeat("visual", 7), repeat("multitask",10), repeat("sum", 10)])))

# %%
def standardize(x):
    return (x-numpy.mean(x))/numpy.std(x)

# %%
ggplot(data, aes(x='epoch', y='recall', color='model')) + geom_line(size=3)  + theme()
# Out:
# <ggplot: (8775988275569)>
